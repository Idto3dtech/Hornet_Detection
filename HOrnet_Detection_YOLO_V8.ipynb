# %%
# !git clone https://github.com/Idto3dtech/Hornet_Detection.git
# Out:
# Cloning into 'Hornet_Detection'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 145 (delta 25), reused 123 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (145/145), 12.21 MiB | 16.84 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
cd /content/Hornet_Detection
# Out:
# /content/Hornet_Detection

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KdNVXu0fIn7H8yhfAJ8j")
project = rf.workspace("hornettrap").project("asian-hornet-detection-a6ael-aogji")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Asian-Hornet-Detection-2 in yolov8:: 100%|██████████| 2330/2330 [00:00<00:00, 5647.34it/s]

# %%
# !pip install -r /content/Hornet_Detection/requirements.txt

# %%
# !python /content/Hornet_Detection/ultralytics/yolo/v8/detect/train.py model=yolov8n.pt data=/content/Hornet_Detection/Asian-Hornet-Detection-2/data.yaml epochs=100
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(self.amp):
#      68/100      3.06G     0.8885     0.7695      1.219         34        640:  50% 36/72 [00:17<00:14,  2.57it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      68/100      3.06G     0.8907     0.7701      1.218         51        640:  51% 37/72 [00:17<00:15,  2.23it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# ...

# %%
# !python /content/Hornet_Detection/ultralytics/yolo/v8/detect/predict.py model='/content/runs/detect/train/weights/best.pt' source='/content/Hornet_Detection/Sample images/Demo-07.jpg'
# Out:
# 2024-09-04 07:36:46.984238: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 07:36:47.005065: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 07:36:47.011067: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 07:36:47.025341: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
